# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("loss_data.pkl", "rb") as f:
    train, val, acc = pickle.load(f)

# %%
# def smooth(li):
#     newli = []


plt.plot(train)

# %%
print(len(train))
# Out:
# 113148

# %%
plt.plot(val[1:])
