# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("loss_data.pkl", "rb") as f:
    train, val = pickle.load(f)

# %%
def smooth(li):
    newli = []
    for ix, i in enumerate(li):


plt.plot(train)

# %%
plt.plot(val[1:])
